# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    
    for filename in filenames:
        os.path.join(dirname, filename)

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

# clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# E:\JupyterLabProgram\Object-detection\yolov5
# ERROR: Invalid requirement: '#'
# Note: you may need to restart the kernel to use updated packages.
# Setup complete. Using torch 1.10.2+cu113 (NVIDIA GeForce RTX 3060 Laptop GPU)

# %%
# %cd yolov5
# %ls
# Out:
#  驱动器 E 中的卷是 文件
#  卷的序列号是 5883-905F
#
#  E:\JupyterLabProgram\Object-detection\yolov5 的目录
#
# 2022/05/24  15:49    <DIR>          .
# 2022/05/24  15:49    <DIR>          ..
# 2022/05/24  15:11             3,610 .dockerignore
# 2022/05/24  15:34    <DIR>          .git
# 2022/05/24  15:11                75 .gitattributes
# 2022/05/24  15:34    <DIR>          .github
# 2022/05/24  15:12             3,976 .gitignore
# 2022/05/24  15:12                 0 __init__.py
# 2022/05/24  15:34    <DIR>          data
# 2022/05/24  15:12             1,809 Dockerfile
# 2022/05/24  15:12            35,126 LICENSE
# 2022/05/24  15:12            11,189 README.md
# 2022/05/24  15:45               703 requirements.txt
# 2022/05/24  15:49       176,120,518 yolov5x.pt
#                9 个文件    176,177,006 字节
#                5 个目录 274,508,619,776 可用字节

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/images/
# Out:
# Namespace(weights=['yolov5x.pt'], source='data/images/', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# image 1/447 E:\JupyterLabProgram\Object-detection\yolov5\data\images\000000.png: 224x640 1 person, 12 bicycles, 1 potted plant, Done. (0.058s)
# image 2/447 E:\JupyterLabProgram\Object-detection\yolov5\data\images\000001.png: 224x640 2 cars, 1 bus, Done. (0.031s)
# image 3/447 E:\JupyterLabProgram\Object-detection\yolov5\data\images\000002.png: 224x640 1 car, 1 truck, Done. (0.026s)
# image 4/447 E:\JupyterLabProgram\Object-detection\yolov5\data\images\000003.png: 224x640 2 cars, Done. (0.027s)
# ...

# %%
Image(filename=('runs/detect/exp2/000000.png'), width=600)

# %%
Image(filename=('runs/detect/exp2/000100.png'), width=600)

# %%
Image(filename=('runs/detect/exp2/000400.png'), width=600)
