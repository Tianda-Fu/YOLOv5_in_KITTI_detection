# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    
    for filename in filenames:
        os.path.join(dirname, filename)

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

# clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# E:\JupyterLabProgram\Object-detection\yolov5
# ERROR: Invalid requirement: '#'
# Note: you may need to restart the kernel to use updated packages.
# Setup complete. Using torch 1.10.2+cu113 (NVIDIA GeForce RTX 3060 Laptop GPU)

# %%
# %cd yolov5
# %ls
# Out:
#  驱动器 E 中的卷是 文件
#  卷的序列号是 5883-905F
#
#  E:\JupyterLabProgram\Object-detection\yolov5 的目录
#
# 2022/06/09  16:18    <DIR>          .
# 2022/06/09  16:18    <DIR>          ..
# 2022/05/24  15:11             3,610 .dockerignore
# 2022/05/24  15:34    <DIR>          .git
# 2022/05/24  15:11                75 .gitattributes
# 2022/05/24  15:34    <DIR>          .github
# 2022/05/24  15:12             3,976 .gitignore
# 2022/05/24  15:57    <DIR>          .ipynb_checkpoints
# 2022/05/24  15:12                 0 __init__.py
# 2022/05/24  15:34    <DIR>          data
# 2022/06/09  16:19    <DIR>          data_object_image_2
# 2022/05/24  15:57             9,434 detect.py
# 2022/05/24  15:12             1,809 Dockerfile
# 2022/05/24  15:12            35,126 LICENSE
# 2022/05/24  16:37    <DIR>          models
# 2022/05/24  15:12            11,189 README.md
# 2022/05/24  15:45               703 requirements.txt
# 2022/05/24  16:34    <DIR>          runs
# ...

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data_object_image_2/training/image_2

# %%
Image(filename=('runs/detect/exp6/000000.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/000030.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/000100.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/000600.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/006000.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/007100.png'), width=600)

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/1.mp4

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/2.mp4

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/3.mp4

# %%
Image(filename=('runs/detect/exp6/000600.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/006000.png'), width=600)

# %%
Image(filename=('runs/detect/exp6/007100.png'), width=600)

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/1.mp4
# Out:
# Namespace(weights=['yolov5x.pt'], source='data/1.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# video 1/1 (1/409) E:\JupyterLabProgram\Object-detection\yolov5\data\1.mp4: 384x640 1 person, 7 cars, 1 bus, 1 truck, 1 traffic light, Done. (0.067s)
# video 1/1 (2/409) E:\JupyterLabProgram\Object-detection\yolov5\data\1.mp4: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, Done. (0.021s)
# video 1/1 (3/409) E:\JupyterLabProgram\Object-detection\yolov5\data\1.mp4: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, Done. (0.021s)
# video 1/1 (4/409) E:\JupyterLabProgram\Object-detection\yolov5\data\1.mp4: 384x640 1 person, 6 cars, 1 bus, 1 traffic light, 1 umbrella, Done. (0.063s)
# ...

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/2.mp4
# Out:
# Namespace(weights=['yolov5x.pt'], source='data/2.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# video 1/1 (1/293) E:\JupyterLabProgram\Object-detection\yolov5\data\2.mp4: 384x640 11 persons, 3 bicycles, 2 cars, 1 bus, 5 traffic lights, 1 backpack, Done. (0.032s)
# video 1/1 (2/293) E:\JupyterLabProgram\Object-detection\yolov5\data\2.mp4: 384x640 11 persons, 3 bicycles, 3 cars, 1 bus, 6 traffic lights, 2 backpacks, Done. (0.022s)
# video 1/1 (3/293) E:\JupyterLabProgram\Object-detection\yolov5\data\2.mp4: 384x640 11 persons, 3 bicycles, 2 cars, 5 traffic lights, 2 backpacks, Done. (0.021s)
# ...

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source data/3.mp4
# Out:
# Namespace(weights=['yolov5x.pt'], source='data/3.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False)
# video 1/1 (1/420) E:\JupyterLabProgram\Object-detection\yolov5\data\3.mp4: 384x640 4 cars, 1 motorcycle, 1 train, Done. (0.030s)
# video 1/1 (2/420) E:\JupyterLabProgram\Object-detection\yolov5\data\3.mp4: 384x640 5 cars, Done. (0.020s)
# video 1/1 (3/420) E:\JupyterLabProgram\Object-detection\yolov5\data\3.mp4: 384x640 6 cars, 1 train, Done. (0.020s)
# video 1/1 (4/420) E:\JupyterLabProgram\Object-detection\yolov5\data\3.mp4: 384x640 4 cars, 1 motorcycle, Done. (0.021s)
# video 1/1 (5/420) E:\JupyterLabProgram\Object-detection\yolov5\data\3.mp4: 384x640 6 cars, Done. (0.020s)
# ...
